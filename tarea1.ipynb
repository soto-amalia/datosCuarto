# %% [markdown]
# ### Tarea de Matriz Identidadconda activate testenv
# Empezamos creando un simple renglon identidad 1x3

# %%
for i in range(3):
    if i == 1:
        print(1,end=" ")
    else:
        print(0,end=" ")
# Out:
# 0 1 0
